# %% [markdown]
# Shell script for accessing GPU kernel on Google Colab through the Colab extension on VS Code.  Connect to a kernel and clone your repository.  run `pip install -r colab_requirements.txt` then do what you need to do

# %% [markdown]
# export PYTHONPATH=/content/ADS599-Capstone:$PYTHONPATH
# python -m modeling.lstm.train

# %% [markdown]
# Uses about 70 gb of RAM even with downcasting so add a filter to remove data
