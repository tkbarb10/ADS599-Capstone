# %% [markdown]
# **Name displayed on main page**
# Patient Portal

# %%
import pandas as pd
from datasets import load_dataset

patient_repo = "ADS599-Capstone/interim_data"
data_repo = "ADS599-Capstone/confidence_delta_data"

patient_df = load_dataset(path=patient_repo, name='cohort_full', split='cohort_base').to_pandas()
data_df = load_dataset(path=data_repo, name='default', split='rl_train').to_pandas()

# %% [markdown]
# # Layout
#
# There will be 1 main page and 3 tabs

# %% [markdown]
# ## First Tab - Basic Patient Info
#
# This lets the user select a patient, and then an ed stay.  This will be a static choice for all 3 tabs

# %% [markdown]
# ### Features
#
# - sidebar will feature a drop down menu for user to select a patient.  The dropdown will show max 10 at a time and user will be able to scroll through the rest
# - the following patient info will be shown
#     - All triage stats

# %% [markdown]
# ## Second Tab
#
# Patient trajectory.  See the full arc of how the confidence changed, or select a step and see, along with what changed from the previous step

# %% [markdown]
# ### Features
#
# - sidebar will allow user to select either whole stay or a specific time step

# %% [markdown]
# ## Third Tab
#
# Patient features the model was using to make its decisions.  For whole stay and see if we can get step by step
